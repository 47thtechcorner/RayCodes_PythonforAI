# %% [markdown]
# <a href="https://colab.research.google.com/github/47thtechcorner/RayCodes_PythonforAI/blob/main/PythonforAI_2_Logics_Decisions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(10==2)
# Out:
# False

# %%
print(10>2)
# Out:
# True

# %%
print(10!=2)
# Out:
# True

# %%
age = 25
isAdult = age >= 18
print(isAdult)
# Out:
# True

# %%
age = 15
if age >= 18:
  print("You are adult")
else:
  print("You are not adult")
# Out:
# You are not adult

# %%
experience = 3
knows_python = True

if experience >= 5 and knows_python:
  print("You are a great developer")
else:
  print("You need to work harder")
# Out:
# You need to work harder

# %%
experience = 3
knows_python = True

if experience >= 5 or knows_python:
  print("You are a great developer")
else:
  print("You need to work harder")
# Out:
# You are a great developer

# %%
sleep = input("Hours slept: ")
screen = input("Screen time hours: ")
# Out:
# Hours slept: 7
# Screen time hours: 9

# %%
type(sleep)
# Out:
# str

# %%
sleep = float(sleep)
screen = float(screen)

# %%
type(sleep)
# Out:
# float

# %%
if sleep < 6 or screen > 10:
    print("HIGH RISK: Burnout Imminent.")
    print("Stop coding and go outside.")
elif sleep < 8:
    print("Sleep is not enough")
else:
    print("HEALTHY: You are balanced.")
# Out:
# Sleep is not enough
