# %% [markdown]
# <a href="https://colab.research.google.com/github/47thtechcorner/RayCodes_PythonforAI/blob/main/PythonforAI_1_Variables_FStrings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "prayas"

# %%
name
# Out:
# 'prayas'

# %%
type(name)
# Out:
# str

# %%
age = 26
type(age)
# Out:
# int

# %%
name = "Prayas"
job = "Data Scientist"
name, job
# Out:
# ('Prayas', 'Data Scientist')

# %%
print(name)
print(job)
# Out:
# Ray
# Data Scientist

# %%
print(f"Hi {name}! Your Job is {job}")
# Out:
# Hi Prayas! Your Job is Data Scientist

# %%
name = input()
# Out:
# Prayas

# %%
name
# Out:
# 'Prayas'

# %%
print("--- Welcome to Brand Builder ---")

name = input("What is your name? ")
skill = input("What is your top skill? ")
dream = input("What are you learning? ")
# Out:
# --- Welcome to Brand Builder ---
# What is your name? Prayas
# What is your top skill? Python
# What are you learning? Python for AI

# %%
bio = f"Hi, I'm {name}. I am an expert in {skill}. currently, I'm learning {dream} to build the future!"

# %%
print("--- YOUR NEW BIO ---")
print(bio)
# Out:
# --- YOUR NEW BIO ---
# Hi, I'm Prayas. I am an expert in Python. currently, I'm learning Python for AI to build the future!
